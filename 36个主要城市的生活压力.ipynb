# %%
import pandas as pd
import plotly as py
import cufflinks as cf

cf.set_config_file(offline=True, theme='ggplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 人口密度

# %%
df = pd.read_csv("人口密度.csv",encoding='gbk')
df[['地区','人口密度']].head()
# Out:
#      地区        人口密度
# 0    北京  838.391225
# 1    天津  905.432781
# 2   石家庄  619.384149
# 3    太原  538.248321
# 4  呼和浩特  142.736879

# %%
df['人口密度'].describe()
# Out:
# count      36.000000
# mean      697.749144
# std       516.344275
# min        18.781760
# 25%       361.142947
# 50%       600.689035
# 75%       923.156006
# max      2306.593060
# Name: 人口密度, dtype: float64

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType


def geo_base() -> Geo:
    c = (
        Geo()
        .add_schema(maptype="china",itemstyle_opts=opts.ItemStyleOpts(color="#323c48", border_color="#111"))
        .add("人/平方千米", zip(list(df.地区),list(df.人口密度)))
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="2018年36个主要城市的人口密度情况"),
            visualmap_opts=opts.VisualMapOpts(max_=2306.6,min_=18.7,is_piecewise=True,
                                             pieces=[{'min':924,'max':2306.593060},{'min':602,'max':923.156006},{'min':362,'max':600.689035},{'min':18.781760,'max':361.142947}]))
    )
    return c

# %%
geo_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="94277655d79a4882879e3e3f02026f31" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_94277655d79a4882879e3e3f02026f31 = echarts.init(
#                     document.getElementById('94277655d79a4882879e3e3f02026f31'), 'white', {renderer: 'canvas'});
#                 var option_94277655d79a4882879e3e3f02026f31 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u4eba/\u5e73\u65b9\u5343\u7c73",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         838.3912249
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         905.4327808
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84",
#                     "value": [
#                         114.48,
#                         38.03,
#                         619.3841494
#                     ]
#                 },
#                 {
#                     "name": "\u592a\u539f",
#                     "value": [
#                         112.53,
#                         37.87,
#                         538.2483212000001
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279",
#                     "value": [
#                         111.65,
#                         40.82,
#                         142.73687880000003
#                     ]
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": [
#                         123.38,
#                         41.8,
#                         576.1430337
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u8fde",
#                     "value": [
#                         121.62,
#                         38.92,
#                         449.6562665
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6625",
#                     "value": [
#                         125.35,
#                         43.88,
#                         365.32458060000005
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         179.19774009999998
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         2306.59306
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         1056.449901
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         466.43769580000003
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u6ce2",
#                     "value": [
#                         121.56,
#                         29.86,
#                         614.2624287000001
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": [
#                         117.27,
#                         31.86,
#                         662.2629969
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5dde",
#                     "value": [
#                         119.3,
#                         26.08,
#                         587.1156417000001
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         1427.4867570000001
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u660c",
#                     "value": [
#                         115.89,
#                         28.68,
#                         718.5625507
#                     ]
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": [
#                         117,
#                         36.65,
#                         640.2772355000001
#                     ]
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": [
#                         120.33,
#                         36.07,
#                         724.862613
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         1160.2202519999998
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         1040.416765
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         616.6849987
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         1247.901533
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         2278.056112
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u5b81",
#                     "value": [
#                         108.33,
#                         22.84,
#                         348.5980463
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": [
#                         110.35,
#                         20.02,
#                         520.0878477
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         413.0530812
#                     ]
#                 },
#                 {
#                     "name":

# %% [markdown]
# 人口密度越大，代表该地人口越多。人口越多通常意味着该地的人口职业竞争可能会相对较激烈，那么该地的劳动力人口的压力可能也会随之较大。通过按照25%的比例递增，将中国36个主要城市（大中城市）的人口密度分为了四个层次。其中，一线城市上海、广州和深圳的人口密度不出所料地排在了前75%（前9位），但北京却位于第11名,那是否意味着北京比其余三个一线城市失业率更高、工资水平更低、消费压力更大等而导致人口流失？同时在前75%中，除一线城市和厦门外，剩余的郑州、南京、武汉、成都、西安都属于今年的新一线城市，可以发现，新一线城市成为了很多人生活和奋斗上的选择。
#
# 前五名：上海、深圳、厦门、广州、郑州
# 后五名：银川、哈尔滨、乌鲁木齐、呼和浩特、拉萨

# %% [markdown]
# # 人均消费支出与平均薪资

# %%
df2 = pd.read_csv("人均消费支出与平均薪资.csv",encoding='gbk')
df2.head()
# Out:
#      地区   平均薪资  居民人均消费支出       差值
# 0  呼和浩特  71387   22714.0  48673.0
# 1    厦门  85166   33192.0  51974.0
# 2   哈尔滨  71771   19221.0  52550.0
# 3    海口  77632   22971.0  54661.0
# 4  乌鲁木齐  85990   28404.0  57586.0

# %%
df2.describe()
# Out:
#                 平均薪资      居民人均消费支出             差值
# count      36.000000     34.000000      34.000000
# mean    92374.583333  25079.117647   67914.411765
# std     18077.509741   7648.599522   14663.338822
# min     71387.000000  11520.000000   48673.000000
# 25%     81991.250000  19580.250000   60259.750000
# 50%     86557.500000  22394.000000   64556.500000
# 75%     95551.000000  29644.000000   69517.750000
# max    149843.000000  43351.000000  115416.000000

# %%
from pyecharts.charts import Line

def line_smooth() -> Line:
    line = (
        Line()
        .add_xaxis(list(df2.地区))
        .add_yaxis("人均消费支出（元）", list(df2.居民人均消费支出))
        .add_yaxis("平均工资（元）", list(df2.平均薪资))
        .set_global_opts(title_opts=opts.TitleOpts(title="平均工资和消费支出的关系"),
            datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
        )
    )
    return line

# %%
line_smooth().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce73da163d234878b2f7aac4fe066391" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce73da163d234878b2f7aac4fe066391 = echarts.init(
#                     document.getElementById('ce73da163d234878b2f7aac4fe066391'), 'white', {renderer: 'canvas'});
#                 var option_ce73da163d234878b2f7aac4fe066391 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4eba\u5747\u6d88\u8d39\u652f\u51fa\uff08\u5143\uff09",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u547c\u548c\u6d69\u7279",
#                     22714.0
#                 ],
#                 [
#                     "\u53a6\u95e8",
#                     33192.0
#                 ],
#                 [
#                     "\u54c8\u5c14\u6ee8",
#                     19221.0
#                 ],
#                 [
#                     "\u6d77\u53e3",
#                     22971.0
#                 ],
#                 [
#                     "\u4e4c\u9c81\u6728\u9f50",
#                     28404.0
#                 ],
#                 [
#                     "\u798f\u5dde",
#                     24917.0
#                 ],
#                 [
#                     "\u77f3\u5bb6\u5e84",
#                     16422.0
#                 ],
#                 [
#                     "\u6b66\u6c49",
#                     28307.0
#                 ],
#                 [
#                     "\u6c88\u9633",
#                     21815.0
#                 ],
#                 [
#                     "\u90d1\u5dde",
#                     20680.0
#                 ],
#                 [
#                     "\u94f6\u5ddd",
#                     25505.0
#                 ],
#                 [
#                     "\u8d35\u9633",
#                     20707.0
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     19248.0
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     27316.0
#                 ],
#                 [
#                     "\u957f\u6625",
#                     16610.0
#                 ],
#                 [
#                     "\u5357\u660c",
#                     18716.0
#                 ],
#                 [
#                     "\u957f\u6c99",
#                     28867.0
#                 ],
#                 [
#                     "\u592a\u539f",
#                     16138.0
#                 ],
#                 [
#                     "\u897f\u5b89",
#                     21723.0
#                 ],
#                 [
#                     "\u897f\u5b81",
#                     18628.0
#                 ],
#                 [
#                     "\u6210\u90fd",
#                     21644.0
#                 ],
#                 [
#                     "\u5927\u8fde",
#                     20577.0
#                 ],
#                 [
#                     "\u5408\u80a5",
#                     21547.0
#                 ],
#                 [
#                     "\u5170\u5dde",
#                     17913.0
#                 ],
#                 [
#                     "\u676d\u5dde",
#                     37369.0
#                 ],
#                 [
#                     "\u6d4e\u5357",
#                     22074.0
#                 ],
#                 [
#                     "\u5b81\u6ce2",
#                     32200.0
#                 ],
#                 [
#                     "\u6df1\u5733",
#                     40535.0
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     29903.0
#                 ],
#                 [
#                     "\u5357\u4eac",
#                     30706.0
#                 ],
#                 [
#                     "\u5e7f\u5dde",
#                     31407.0
#                 ],
#                 [
#                     "\u4e0a\u6d77",
#                     43351.0
#                 ],
#                 [
#                     "\u5317\u4eac",
#                     39843.0
#                 ],
#                 [
#                     "\u62c9\u8428",
#                     11520.0
#                 ],
#                 [
#                     "\u5357\u5b81",
#                     null
#                 ],
#                 [
#                     "\u6606\u660e",
#                     null
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5de5\u8d44\uff08\u5143\uff09",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u547c\u548c\u6d69\u7279",
#                     71387
#                 ],
#                 [
#                     "\u53a6\u95e8",
#                     85166
#                 ],
#                 [
#                     "\u54c8\u5c14\u6ee8",
#                     71771
#                 ],
#                 [
#                     "\u6d77\u53e3",
#                     77632
#                 ],
#                 [
#                     "\u4e4c\u9c81\u6728\u9f50",
#                     85990
#                 ],
#                 [
#                     "\u798f\u5dde",
#                     83175
#                 ],
#                 [
#                     "\u77f3\u5bb6\u5e84",
#                     75114
#                 ],
#                 [
#                     "\u6b66\u6c49",
#                     88327
#                 ],
#                 [
#                     "\u6c88\u9633",
#                     82067
#                 ],
#                 [
#                     "\u90d1\u5dde",
#                     80963
#                 ],
#                 [
#                     "\u94f6\u5ddd",
#                     87291
#                 ],
#                 [
#                     "\u8d35\u9633",
#                     82685
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     81764
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     90840
#                 ],
#                 [
#                     "\u957f\u6625",
#                     80425
#                 ],
#                 [
#                     "\u5357\u660c",
#                     82672
#                 ],
#                 [
#                     "\u957f\u6c99",
#                     93293
#                 ],
#                 [
#                     "\u592a\u539f",
#                     80825
#                 ],
#                 [
#                     "\u897f\u5b89",
#                     87125
#                 ],
#                 [
#                     "\u897f\u5b81",
#                     84071
#                 ],
#                 [

# %% [markdown]
# 由图中可看出，两条折线的运动趋势相似，由此可以判断出消费支出与薪酬呈显性的正比关系，也就是说薪酬越高的城市，其消费支出也会相应越高。其中，有趣的发现是，位于偏远地区的拉萨，人们平均工资达到每年12.6936万元,仅次于北京和上海，位居第3。并且，从已知的平均工资的数据来看，拉萨的人均消费支出在36个主要城市中是最低的。由此可以判断出，在36个主要城市中，拉萨居民在财力上的压力是最小的。

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


def chazhi() -> Bar:
    c = (
        Bar()
        .add_xaxis(list(df2.地区))
        .add_yaxis("差值", list(df2.差值))
        .set_global_opts(title_opts=opts.TitleOpts(title="差值", subtitle="平均工资-人均消费支出"),
                        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],)
    )
    return c

# %%
chazhi().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="90aabd8dea544b558f276200c2ef1dd0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_90aabd8dea544b558f276200c2ef1dd0 = echarts.init(
#                     document.getElementById('90aabd8dea544b558f276200c2ef1dd0'), 'white', {renderer: 'canvas'});
#                 var option_90aabd8dea544b558f276200c2ef1dd0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5dee\u503c",
#             "data": [
#                 48673.0,
#                 51974.0,
#                 52550.0,
#                 54661.0,
#                 57586.0,
#                 58258.0,
#                 58692.0,
#                 60020.0,
#                 60252.0,
#                 60283.0,
#                 61786.0,
#                 61978.0,
#                 62516.0,
#                 63524.0,
#                 63815.0,
#                 63956.0,
#                 64426.0,
#                 64687.0,
#                 65402.0,
#                 65443.0,
#                 66367.0,
#                 67015.0,
#                 67475.0,
#                 67662.0,
#                 69340.0,
#                 69577.0,
#                 70125.0,
#                 71174.0,
#                 74028.0,
#                 80365.0,
#                 80432.0,
#                 99632.0,
#                 110000.0,
#                 115416.0,
#                 null,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5dee\u503c"
#             ],
#             "selected": {
#                 "\u5dee\u503c": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u547c\u548c\u6d69\u7279",
#                 "\u53a6\u95e8",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u6d77\u53e3",
#                 "\u4e4c\u9c81\u6728\u9f50",
#                 "\u798f\u5dde",
#                 "\u77f3\u5bb6\u5e84",
#                 "\u6b66\u6c49",
#                 "\u6c88\u9633",
#                 "\u90d1\u5dde",
#                 "\u94f6\u5ddd",
#                 "\u8d35\u9633",
#                 "\u91cd\u5e86",
#                 "\u9752\u5c9b",
#                 "\u957f\u6625",
#                 "\u5357\u660c",
#                 "\u957f\u6c99",
#                 "\u592a\u539f",
#                 "\u897f\u5b89",
#                 "\u897f\u5b81",
#                 "\u6210\u90fd",
#                 "\u5927\u8fde",
#                 "\u5408\u80a5",
#                 "\u5170\u5dde",
#                 "\u676d\u5dde",
#                 "\u6d4e\u5357",
#                 "\u5b81\u6ce2",
#                 "\u6df1\u5733",
#                 "\u5929\u6d25",
#                 "\u5357\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u62c9\u8428",
#                 "\u5357\u5b81",
#                 "\u6606\u660e"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5dee\u503c",
#             "subtext": "\u5e73\u5747\u5de5\u8d44-\u4eba\u5747\u6d88\u8d39\u652f\u51fa"
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         },
#         {
#             "show": true,
#             "type": "inside",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         }
#     ]
# };
#                 chart_90aabd8dea544b558f276200c2ef1dd0.setOption(option_90aabd8dea544b558f276200c2ef1dd0);
#         });
#     </script>

# %%
dfa=df2.set_index('地区').loc[:,['差值']]

# %%
dfa.iplot(kind="bar", xTitle="地区",yTitle="差值", title="差值" )
# Out:
# <div>
#
#
#             <div id="59a8c104-b1cd-41fd-a6d1-203c49c79916" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("59a8c104-b1cd-41fd-a6d1-203c49c79916")) {
#                     Plotly.newPlot(
#                         '59a8c104-b1cd-41fd-a6d1-203c49c79916',
#                         [{"marker": {"color": "rgba(226, 74, 51, 0.6)", "line": {"color": "rgba(226, 74, 51, 1.0)", "width": 1}}, "name": "\u5dee\u503c", "orientation": "v", "text": "", "type": "bar", "x": ["\u547c\u548c\u6d69\u7279", "\u53a6\u95e8", "\u54c8\u5c14\u6ee8", "\u6d77\u53e3", "\u4e4c\u9c81\u6728\u9f50", "\u798f\u5dde", "\u77f3\u5bb6\u5e84", "\u6b66\u6c49", "\u6c88\u9633", "\u90d1\u5dde", "\u94f6\u5ddd", "\u8d35\u9633", "\u91cd\u5e86", "\u9752\u5c9b", "\u957f\u6625", "\u5357\u660c", "\u957f\u6c99", "\u592a\u539f", "\u897f\u5b89", "\u897f\u5b81", "\u6210\u90fd", "\u5927\u8fde", "\u5408\u80a5", "\u5170\u5dde", "\u676d\u5dde", "\u6d4e\u5357", "\u5b81\u6ce2", "\u6df1\u5733", "\u5929\u6d25", "\u5357\u4eac", "\u5e7f\u5dde", "\u4e0a\u6d77", "\u5317\u4eac", "\u62c9\u8428", "\u5357\u5b81", "\u6606\u660e"], "y": [48673.0, 51974.0, 52550.0, 54661.0, 57586.0, 58258.0, 58692.0, 60020.0, 60252.0, 60283.0, 61786.0, 61978.0, 62516.0, 63524.0, 63815.0, 63956.0, 64426.0, 64687.0, 65402.0, 65443.0, 66367.0, 67015.0, 67475.0, 67662.0, 69340.0, 69577.0, 70125.0, 71174.0, 74028.0, 80365.0, 80432.0, 99632.0, 110000.0, 115416.0, "", ""]}],
#                         {"legend": {"bgcolor": "#FFFFFF", "font": {"color": "#666666"}}, "paper_bgcolor": "#FFFFFF", "plot_bgcolor": "#E5E5E5", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %% [markdown]
# 由平均工资和消费支出关系图可以看出，人均消费支出中最突出的是北京、上海和深圳，基本达到4万左右。那么从平均工资减去人均消费支出后所剩的储蓄即差值来看，在36个城市中北京、上海的人均的基本储蓄是比较高的，基本可以达到10万左右，而相对北京和上海来说的深圳人均的基本储蓄比较低，为7万1千多。由此大致可知，在一线城市中，深圳的居民消费压力是最大的。
#
# 并且从差值图中也能直观地看出，在36个城市中，呼和浩特的居民消费压力是最大的。36个主要城市中人均消费支出的平均值是25079，呼和浩特的人均消费支出是低于平均值的，那么呼和浩特人均的基本储蓄最低主要原因在于当地居民的平均工资比较低，其平均工资是36个主要城市中的最低的，呼和浩特人口密度小原因之一或许也正是因为呼和浩特低工资。
#
#
# 前五名：拉萨、北京、上海、广州、南京
# 后五名：呼和浩特、厦门、哈尔滨、海口、乌鲁木齐

# %% [markdown]
# # 住宅商品房平均房价

# %%
df3 = pd.read_csv("住宅商品房平均房价.csv",encoding='gbk')
df3.head()
# Out:
#    地区     2018年    2017年    2016年    2015年    2014年    2013年     2012年  \
# 0  深圳  55441.01  48622.0  45498.0  33661.0  24040.0  23427.0  18995.92
# 1  北京  37420.19  34117.0  28489.0  22300.0  18499.0  17854.0  16553.48
# 2  上海  28981.11  24866.0  25910.0  21501.0  16415.0  16192.0  13869.88
# 3  厦门  33715.43  28053.0  25251.0  18928.0  17778.0  14551.0  12953.38
# 4  南京  19708.33  15259.0  17884.0  11260.0  10964.0  11078.0   9674.84
#
#       2011年    2010年    2009年
# 0  21037.05  18954.0  14389.0
# 1  15517.90  17151.0  13224.0
# 2  13565.83  14290.0  12364.0
# 3  13422.59  11590.0   8935.0
# 4   8414.62   9227.0   6893.0

# %%
df3.describe()
# Out:
#               2018年         2017年         2016年         2015年         2014年  \
# count     35.000000     35.000000     35.000000     35.000000     35.000000
# mean   14411.196000  12414.600000  11034.485714   9519.971429   8598.742857
# std    10428.099736   9132.826549   8544.984189   6151.713350   4651.173169
# min     5589.490000   4892.000000   4448.000000   4498.000000   4111.000000
# 25%     8220.610000   7493.500000   6250.000000   6181.500000   5802.500000
# 50%    10840.490000   8827.000000   7707.000000   7303.000000   6579.000000
# 75%    15152.760000  12919.500000  11398.000000  10476.500000   9513.000000
# max    55441.010000  48622.000000  45498.000000  33661.000000  24040.000000
#
#               2013年         2012年         2011年         2010年         2009年
# count     35.000000     35.000000     35.000000     35.000000     35.000000
# mean    8372.685714   7718.497714   7439.300000   7059.800000   5705.971429
# std     4424.655499   3709.090984   3903.408026   4047.242277   3055.166911
# min     4380.000000   4187.260000   3438.600000   3196.000000   2811.000000
# 25%     5744.000000   5339.125000   4831.035000   4293.500000   3611.500000
# 50%     6639.000000   6224.030000   5969.660000   5502.000000   4463.000000
# 75%     9272.500000   8842.210000   8481.130000   8004.500000   6523.000000
# max    23427.000000  18995.920000  21037.050000  18954.000000  14389.000000

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Page, Pie, Timeline

def timeline2() -> Timeline:
    x = list(df3.地区)
    t2 = Timeline()
    for i in range(2009, 2019):
        c = (
        Line()
        .add_xaxis(x)
        .add_yaxis("住宅商品房平均房价", list(df3["{}年".format(i)]))
        .set_global_opts(title_opts=opts.TitleOpts("{}年各城市住宅商品房平均房价".format(i)),
                             datazoom_opts=opts.DataZoomOpts(type_="inside"),
                             visualmap_opts=opts.VisualMapOpts(max_=56000,min_=2811),
                             yaxis_opts=opts.AxisOpts(max_=56000,min_=2811))
        )
        
        t2.add(c, "{}年".format(i),)
    return t2

# %%
timeline2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6bacff384449415e961d3466966e91b3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6bacff384449415e961d3466966e91b3 = echarts.init(
#                     document.getElementById('6bacff384449415e961d3466966e91b3'), 'white', {renderer: 'canvas'});
#                 var option_6bacff384449415e961d3466966e91b3 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "line",
#                 "name": "\u4f4f\u5b85\u5546\u54c1\u623f\u5e73\u5747\u623f\u4ef7",
#                 "connectNulls": false,
#                 "symbolSize": 4,
#                 "showSymbol": true,
#                 "smooth": false,
#                 "step": false,
#                 "data": [
#                     [
#                         "\u6df1\u5733",
#                         55441.01
#                     ],
#                     [
#                         "\u5317\u4eac",
#                         37420.19
#                     ],
#                     [
#                         "\u4e0a\u6d77",
#                         28981.11
#                     ],
#                     [
#                         "\u53a6\u95e8",
#                         33715.43
#                     ],
#                     [
#                         "\u5357\u4eac",
#                         19708.33
#                     ],
#                     [
#                         "\u5e7f\u5dde",
#                         21581.78
#                     ],
#                     [
#                         "\u676d\u5dde",
#                         24360.2
#                     ],
#                     [
#                         "\u5929\u6d25",
#                         15924.26
#                     ],
#                     [
#                         "\u5b81\u6ce2",
#                         16201.58
#                     ],
#                     [
#                         "\u798f\u5dde",
#                         14381.26
#                     ],
#                     [
#                         "\u6b66\u6c49",
#                         12678.48
#                     ],
#                     [
#                         "\u5408\u80a5",
#                         13068.63
#                     ],
#                     [
#                         "\u5927\u8fde",
#                         11432.55
#                     ],
#                     [
#                         "\u9752\u5c9b",
#                         12373.44
#                     ],
#                     [
#                         "\u6d77\u53e3",
#                         12644.47
#                     ],
#                     [
#                         "\u6d4e\u5357",
#                         12161.45
#                     ],
#                     [
#                         "\u90d1\u5dde",
#                         8155.94
#                     ],
#                     [
#                         "\u5357\u660c",
#                         8275.87
#                     ],
#                     [
#                         "\u6210\u90fd",
#                         9783.16
#                     ],
#                     [
#                         "\u77f3\u5bb6\u5e84",
#                         10398.93
#                     ],
#                     [
#                         "\u592a\u539f",
#                         10840.49
#                     ],
#                     [
#                         "\u6606\u660e",
#                         11085.48
#                     ],
#                     [
#                         "\u6c88\u9633",
#                         8680.11
#                     ],
#                     [
#                         "\u5357\u5b81",
#                         7697.27
#                     ],
#                     [
#                         "\u897f\u5b89",
#                         9984.54
#                     ],
#                     [
#                         "\u54c8\u5c14\u6ee8",
#                         8931.92
#                     ],
#                     [
#                         "\u5170\u5dde",
#                         7231.87
#                     ],
#                     [
#                         "\u957f\u6c99",
#                         7796.2
#                     ],
#                     [
#                         "\u957f\u6625",
#                         8091.85
#                     ],
#                     [
#                         "\u4e4c\u9c81\u6728\u9f50",
#                         7757.03
#                     ],
#                     [
#                         "\u8d35\u9633",
#                         8842.96
#                     ],
#                     [
#                         "\u547c\u548c\u6d69\u7279",
#                         8251.24
#                     ],
#                     [
#                         "\u91cd\u5e86",
#                         8189.98
#                     ],
#                     [
#                         "\u897f\u5b81",
#                         6733.36
#                     ],
#                     [
#                         "\u94f6\u5ddd",
#                         5589.49
#                     ],
#                     [
#                         "\u62c9\u8428",
#                         null
#                     ]
#                 ],
#                 "hoverAnimation": true,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 },
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2009\u5e74",
#                 "2010\u5e74",
#                 "2011\u5e74",
#                 "2012\u5e74",
#                 "2013\u5e74",
#                 "2014\u5e74",
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u6df1\u5733",
#                     "\u5317\u4eac",
#                     "\u4e0a\u6d77",
#                     "\u53a6\u95e8",
#                     "\u5357\u4eac",
#                     "\u5e7f\u5dde",
#                     "\u676d\u5dde",
#                     "\u5929\u6d25",
#                     "\u5b81\u6ce2",
#                     "\u798f\u5dde",
#                     "\u6b66\u6c49",
#                     "\u5408\u80a5",
#                     "\u5927\u8fde",
#                     "\u9752\u5c9b",
#                     "\u6d77\u53e3",
#                     "\u6d4e\u5357",
#                     "\u90d1\u5dde",
#                     "\u5357\u660c",
#                     "\u6210\u90fd",
#                     "\u77f3\u5bb6\u5e84",
#                     "\u592a\u539f",
#                     "\u6606\u660e",
#                     "\u6c88\u9633",
#                     "\u5357\u5b81",
#                     "\u897f\u5b89",
#                     "\u54c8\u5c14\u6ee8",
#                     "\u5170\u5dde",
#                     "\u957f\u6c99",
#                     "\u957f\u6625

# %% [markdown]
# 现代结婚最重要的设施就是房子，也是现代年轻人压力的重要来源。那么近10年来36个主要城市的房价走势和未来的趋势会怎样呢？由图表可知，前7年大多数城市的房价上升趋势比较缓和。但自2016开始大多数地区房价出现暴涨，主要在于2015年底国务院出台去库存政策刺激房地产，房价就在深圳等一线城市出现疯涨的行情，楼市“四小龙”南京、合肥、厦门、苏州接棒领衔，其它一、二线热点城市纷纷轮番上涨。可以发现2018年房价上涨稍微放缓，预测未来几年房价依旧会上涨，但是涨幅会缩小。
# 那么近10年房价涨幅比较低的城市有银川、南宁、兰州、西宁、长春。

# %%
from pyecharts.charts import Line

def line_smooth2() -> Line:
    line = (
        Bar()
        .add_xaxis(list(df2.地区))
        .add_yaxis("2009年", list(df3['2009年']))
        .add_yaxis("2010年", list(df3['2010年']))
        .add_yaxis("2011年", list(df3['2011年']))
        .set_global_opts(title_opts=opts.TitleOpts(title="2009-2011年各城市住宅商品房平均房价变化"),
                         legend_opts=opts.LegendOpts(pos_left=380),
            datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
        )
    )
    return line

# %%
line_smooth2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="942ef71ef0df4732a3aa353175bf2093" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_942ef71ef0df4732a3aa353175bf2093 = echarts.init(
#                     document.getElementById('942ef71ef0df4732a3aa353175bf2093'), 'white', {renderer: 'canvas'});
#                 var option_942ef71ef0df4732a3aa353175bf2093 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "2009\u5e74",
#             "data": [
#                 14389.0,
#                 13224.0,
#                 12364.0,
#                 8935.0,
#                 6893.0,
#                 8988.0,
#                 10613.0,
#                 6605.0,
#                 9068.0,
#                 6441.0,
#                 5199.0,
#                 4095.0,
#                 6175.0,
#                 5383.0,
#                 5293.0,
#                 4790.0,
#                 4057.0,
#                 3637.0,
#                 4864.0,
#                 3688.0,
#                 4499.0,
#                 3586.0,
#                 4196.0,
#                 4463.0,
#                 3749.0,
#                 4146.0,
#                 3499.0,
#                 3533.0,
#                 4012.0,
#                 3285.0,
#                 3496.0,
#                 3248.0,
#                 3266.0,
#                 2811.0,
#                 3219.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2010\u5e74",
#             "data": [
#                 18954.0,
#                 17151.0,
#                 14290.0,
#                 11590.0,
#                 9227.0,
#                 10615.0,
#                 14259.0,
#                 7940.0,
#                 11669.0,
#                 7877.0,
#                 5550.0,
#                 5502.0,
#                 6759.0,
#                 6421.0,
#                 8069.0,
#                 6100.0,
#                 4596.0,
#                 4331.0,
#                 5827.0,
#                 3807.0,
#                 7088.0,
#                 3405.0,
#                 5109.0,
#                 4942.0,
#                 4341.0,
#                 5196.0,
#                 4065.0,
#                 4322.0,
#                 5097.0,
#                 4265.0,
#                 4233.0,
#                 3650.0,
#                 4040.0,
#                 3196.0,
#                 3610.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2011\u5e74",
#             "data": [
#                 21037.05,
#                 15517.9,
#                 13565.83,
#                 13422.59,
#                 8414.62,
#                 10925.84,
#                 12748.62,
#                 8547.64,
#                 11285.64,
#                 9553.18,
#                 6675.99,
#                 5607.55,
#                 7928.98,
#                 7166.19,
#                 6641.27,
#                 6663.89,
#                 4692.29,
#                 5322.66,
#                 6360.89,
#                 4352.15,
#                 6517.47,
#                 4550.12,
#                 5612.96,
#                 4995.89,
#                 5829.79,
#                 5216.66,
#                 4229.09,
#                 5481.49,
#                 5969.66,
#                 4969.78,
#                 4587.98,
#                 4073.32,
#                 4492.3,
#                 3438.6,
#                 3979.62,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2009\u5e74",
#                 "2010\u5e74",
#                 "2011\u5e74"
#             ],
#             "selected": {
#                 "2009\u5e74": true,
#                 "2010\u5e74": true,
#                 "2011\u5e74": true
#             },
#             "show": true,
#             "left": 380,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u547c\u548c\u6d69\u7279",
#                 "\u53a6\u95e8",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u6d77\u53e3",
#                 "\u4e4c\u9c81\u6728\u9f50",
#                 "\u798f\u5dde",
#                 "\u77f3\u5bb6\u5e84",
#                 "\u6b66\u6c49",
#                 "\u6c88\u9633",
#                 "\u90d1\u5dde",
#                 "\u94f6\u5ddd",
#                 "\u8d35\u9633",
#                 "\u91cd\u5e86",
#                 "\u9752\u5c9b",
#                 "\u957f\u6625",
#                 "\u5357\u660c",
#                 "\u957f\u6c99",
#                 "\u592a\u539f",
#                 "\u897f\u5b89",
#                 "\u897f\u5b81",
#                 "\u6210\u90fd",
#                 "\u5927\u8fde",
#                 "\u5408\u80a5",
#                 "\u5170\u5dde",
#                 "\u676d\u5dde",
#                 "\u6d4e\u5357",
#                 "\u5b81\u6ce2",
#                 "\u6df1\u5733",
#                 "\u5929\u6d25",
#                 "\u5357\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u62c9\u8428",
#                 "\u5357\u5b81",
#                 "\u6606\u660e"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "2009-2011\u5e74\u5404\u57ce\u5e02\u4f4f\u5b85\u5546\u54c1\u623f\u5e73\u5

# %%
from pyecharts.charts import Line

def line_smooth3() -> Line:
    line = (
        Bar()
        .add_xaxis(list(df2.地区))
        .add_yaxis("2012年", list(df3['2012年']))
        .add_yaxis("2013年", list(df3['2013年']))
        .add_yaxis("2014年", list(df3['2014年']))
        .set_global_opts(title_opts=opts.TitleOpts(title="2012-2014年各城市住宅商品房平均房价变化"),
                         legend_opts=opts.LegendOpts(pos_left=380),
            datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
        )
    )
    return line

# %%
line_smooth3().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="214a2a3a061b46ff8c999b3cea0cd390" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_214a2a3a061b46ff8c999b3cea0cd390 = echarts.init(
#                     document.getElementById('214a2a3a061b46ff8c999b3cea0cd390'), 'white', {renderer: 'canvas'});
#                 var option_214a2a3a061b46ff8c999b3cea0cd390 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "2012\u5e74",
#             "data": [
#                 18995.92,
#                 16553.48,
#                 13869.88,
#                 12953.38,
#                 9674.84,
#                 12000.88,
#                 13291.65,
#                 8009.58,
#                 11385.25,
#                 10644.52,
#                 6895.35,
#                 5754.31,
#                 7583.97,
#                 7583.36,
#                 6512.03,
#                 6650.56,
#                 5643.07,
#                 5879.99,
#                 6678.46,
#                 4713.54,
#                 6404.74,
#                 5404.9,
#                 5989.45,
#                 5618.65,
#                 6224.03,
#                 5112.85,
#                 5420.67,
#                 5602.51,
#                 5273.35,
#                 5255.04,
#                 4472.69,
#                 4798.17,
#                 4804.8,
#                 4304.29,
#                 4187.26,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2013\u5e74",
#             "data": [
#                 23427.0,
#                 17854.0,
#                 16192.0,
#                 14551.0,
#                 11078.0,
#                 13954.0,
#                 14679.0,
#                 8390.0,
#                 11405.0,
#                 10155.0,
#                 7238.0,
#                 6084.0,
#                 7859.0,
#                 7987.0,
#                 7342.0,
#                 7013.0,
#                 6587.0,
#                 6639.0,
#                 6708.0,
#                 4943.0,
#                 6668.0,
#                 5615.0,
#                 6074.0,
#                 6155.0,
#                 6435.0,
#                 5884.0,
#                 5520.0,
#                 5759.0,
#                 5729.0,
#                 5858.0,
#                 4488.0,
#                 4631.0,
#                 5239.0,
#                 4380.0,
#                 4524.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2014\u5e74",
#             "data": [
#                 24040.0,
#                 18499.0,
#                 16415.0,
#                 17778.0,
#                 10964.0,
#                 14739.0,
#                 14035.0,
#                 8828.0,
#                 10890.0,
#                 10105.0,
#                 7399.0,
#                 6917.0,
#                 8921.0,
#                 7855.0,
#                 7473.0,
#                 7158.0,
#                 6579.0,
#                 6225.0,
#                 6536.0,
#                 5562.0,
#                 7155.0,
#                 6067.0,
#                 5865.0,
#                 6103.0,
#                 6105.0,
#                 5751.0,
#                 5860.0,
#                 5458.0,
#                 5847.0,
#                 5758.0,
#                 4904.0,
#                 5153.0,
#                 5094.0,
#                 4807.0,
#                 4111.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2012\u5e74",
#                 "2013\u5e74",
#                 "2014\u5e74"
#             ],
#             "selected": {
#                 "2012\u5e74": true,
#                 "2013\u5e74": true,
#                 "2014\u5e74": true
#             },
#             "show": true,
#             "left": 380,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u547c\u548c\u6d69\u7279",
#                 "\u53a6\u95e8",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u6d77\u53e3",
#                 "\u4e4c\u9c81\u6728\u9f50",
#                 "\u798f\u5dde",
#                 "\u77f3\u5bb6\u5e84",
#                 "\u6b66\u6c49",
#                 "\u6c88\u9633",
#                 "\u90d1\u5dde",
#                 "\u94f6\u5ddd",
#                 "\u8d35\u9633",
#                 "\u91cd\u5e86",
#                 "\u9752\u5c9b",
#                 "\u957f\u6625",
#                 "\u5357\u660c",
#                 "\u957f\u6c99",
#                 "\u592a\u539f",
#                 "\u897f\u5b89",
#                 "\u897f\u5b81",
#                 "\u6210\u90fd",
#                 "\u5927\u8fde",
#                 "\u5408\u80a5",
#                 "\u5170\u5dde",
#                 "\u676d\u5dde",
#                 "\u6d4e\u5357",
#                 "\u5b81\u6ce2",
#                 "\u6df1\u5733",
#                 "\u5929\u6d25",
#                 "\u5357\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u62c9\u8428",
#                 "\u5357\u5b81",
#                 "\u6606\u660e"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "2012-2014\u5e74\u5404\u57ce\u5e02\u4f4f\u5b85\u5546\u54c1\u623f

# %%
from pyecharts.charts import Line

def line_smooth4() -> Line:
    line = (
        Bar()
        .add_xaxis(list(df2.地区))
        .add_yaxis("2015年", list(df3['2015年']))
        .add_yaxis("2016年", list(df3['2016年']))
        .add_yaxis("2017年", list(df3['2017年']))
        .add_yaxis("2018年", list(df3['2018年']))
        .set_global_opts(title_opts=opts.TitleOpts(title="2015-2018年各城市住宅商品房平均房价变化"),
                         legend_opts=opts.LegendOpts(pos_left=380),
                         datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
        )
    )
    return line

# %%
line_smooth4().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="03e931ee65db4822b90fab5ff3a64c47" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_03e931ee65db4822b90fab5ff3a64c47 = echarts.init(
#                     document.getElementById('03e931ee65db4822b90fab5ff3a64c47'), 'white', {renderer: 'canvas'});
#                 var option_03e931ee65db4822b90fab5ff3a64c47 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "2015\u5e74",
#             "data": [
#                 33661.0,
#                 22300.0,
#                 21501.0,
#                 18928.0,
#                 11260.0,
#                 14083.0,
#                 14748.0,
#                 9931.0,
#                 11022.0,
#                 11333.0,
#                 8404.0,
#                 7512.0,
#                 8711.0,
#                 8437.0,
#                 7636.0,
#                 7527.0,
#                 7223.0,
#                 6955.0,
#                 6584.0,
#                 7798.0,
#                 7303.0,
#                 7178.0,
#                 6416.0,
#                 6229.0,
#                 6221.0,
#                 6124.0,
#                 6089.0,
#                 5544.0,
#                 6374.0,
#                 6142.0,
#                 4967.0,
#                 4946.0,
#                 5012.0,
#                 4602.0,
#                 4498.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2016\u5e74",
#             "data": [
#                 45498.0,
#                 28489.0,
#                 25910.0,
#                 25251.0,
#                 17884.0,
#                 16346.0,
#                 16211.0,
#                 12870.0,
#                 11738.0,
#                 11058.0,
#                 9819.0,
#                 9312.0,
#                 9119.0,
#                 8997.0,
#                 8868.0,
#                 8405.0,
#                 8093.0,
#                 7707.0,
#                 7377.0,
#                 7354.0,
#                 7348.0,
#                 6851.0,
#                 6838.0,
#                 6767.0,
#                 6385.0,
#                 6338.0,
#                 6162.0,
#                 6160.0,
#                 6018.0,
#                 5829.0,
#                 5392.0,
#                 5196.0,
#                 5162.0,
#                 5007.0,
#                 4448.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2017\u5e74",
#             "data": [
#                 48622.0,
#                 34117.0,
#                 24866.0,
#                 28053.0,
#                 15259.0,
#                 17685.0,
#                 21225.0,
#                 15139.0,
#                 14145.0,
#                 10547.0,
#                 11453.0,
#                 11442.0,
#                 10019.0,
#                 10052.0,
#                 11694.0,
#                 9712.0,
#                 8323.0,
#                 8106.0,
#                 8595.0,
#                 9738.0,
#                 8827.0,
#                 8197.0,
#                 7944.0,
#                 7700.0,
#                 8166.0,
#                 7861.0,
#                 7137.0,
#                 7287.0,
#                 6811.0,
#                 6188.0,
#                 6552.0,
#                 5662.0,
#                 6605.0,
#                 5890.0,
#                 4892.0,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "2018\u5e74",
#             "data": [
#                 55441.01,
#                 37420.19,
#                 28981.11,
#                 33715.43,
#                 19708.33,
#                 21581.78,
#                 24360.2,
#                 15924.26,
#                 16201.58,
#                 14381.26,
#                 12678.48,
#                 13068.63,
#                 11432.55,
#                 12373.44,
#                 12644.47,
#                 12161.45,
#                 8155.94,
#                 8275.87,
#                 9783.16,
#                 10398.93,
#                 10840.49,
#                 11085.48,
#                 8680.11,
#                 7697.27,
#                 9984.54,
#                 8931.92,
#                 7231.87,
#                 7796.2,
#                 8091.85,
#                 7757.03,
#                 8842.96,
#                 8251.24,
#                 8189.98,
#                 6733.36,
#                 5589.49,
#                 null
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74"
#             ],
#             "selected": {
#                 "2015\u5e74": true,
#                 "2016\u5e74": true,
#                 "2017\u5e74": true,
#                 "2018\u5e74": true
#             },
#             "show": true,
#             "left": 380,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u547c\u548c\u6d69\u7279",
#                 "\u53a6\u95e8",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u6d77\u53e3",
#                 "\u4e4c\u9c81\u6728\u9f50",
#                 "\u798f\u5dde",
#                 "\u77f3\u5bb6\u5e84",
#                 "\u6b66\u6c49",
#                 "\u6c88\u9633",
#                 "\u90d1\u5dde",
#                 "\u94f6\u5ddd",
#                 "\u8d35\u9633",
#                 "\u91cd\u5e86",
#                 "\u9752\u5c9b",
#                 "\u957f\u6625",
#                 "\u5357\u660c",
#                 "\u957f\u6c99",
#                 "\u592a\u539f",
#                 "\u897f\u5b89",

# %% [markdown]
# # 失业率

# %%
df4 = pd.read_csv("失业率.csv",encoding='gbk')
df4.head()
# Out:
#      地区  2018年  2017年  2016年  2015年  2014年
# 0   哈尔滨   3.76   3.68   3.76   3.88   3.72
# 1  呼和浩特   3.60   3.65   3.66   3.56   3.50
# 2    银川   3.58   3.61   3.92   4.05   4.09
# 3    上海   3.57   3.90   4.10   4.10   4.20
# 4   石家庄   3.50   3.90   4.10   4.00   4.10

# %%
df4.describe()
# Out:
#            2018年      2017年      2016年      2015年      2014年
# count  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    2.727500   2.819722   2.870556   2.834444   2.843889
# std     0.698531   0.702524   0.776674   0.810056   0.781710
# min     1.340000   1.300000   0.900000   0.900000   1.310000
# 25%     2.185000   2.350000   2.297500   2.200000   2.260000
# 50%     2.940000   2.930000   3.015000   2.990000   2.965000
# 75%     3.347500   3.402500   3.470000   3.447500   3.425000
# max     3.760000   3.900000   4.100000   4.100000   4.200000

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Page, Pie, Timeline


def timeline2() -> Timeline:
    x = list(df4.地区)
    tl = Timeline()
    for i in range(2014, 2019):
        bar = (
            Bar()
            .add_xaxis(x)
            .add_yaxis("失业率", list(df4["{}年".format(i)]))
            .set_global_opts(title_opts=opts.TitleOpts("{}年各城市失业率".format(i)),
                             datazoom_opts=(opts.DataZoomOpts(type_="inside")),
                             visualmap_opts=opts.VisualMapOpts(max_=4.5,min_=0),
                            yaxis_opts=opts.AxisOpts(max_=4.5,min_=0)))
        tl.add(bar, "{}年".format(i),)
    return tl

# %%
timeline2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="963b76b1447d484980488d959613732e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_963b76b1447d484980488d959613732e = echarts.init(
#                     document.getElementById('963b76b1447d484980488d959613732e'), 'white', {renderer: 'canvas'});
#                 var option_963b76b1447d484980488d959613732e = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u5931\u4e1a\u7387",
#                 "data": [
#                     3.76,
#                     3.6,
#                     3.58,
#                     3.57,
#                     3.5,
#                     3.5,
#                     3.48,
#                     3.42,
#                     3.4,
#                     3.33,
#                     3.26,
#                     3.24,
#                     3.11,
#                     3.1,
#                     3.09,
#                     3.02,
#                     3.0,
#                     2.94,
#                     2.94,
#                     2.58,
#                     2.51,
#                     2.46,
#                     2.45,
#                     2.41,
#                     2.34,
#                     2.3,
#                     2.2,
#                     2.14,
#                     2.09,
#                     2.06,
#                     1.9,
#                     1.79,
#                     1.78,
#                     1.6,
#                     1.4,
#                     1.34
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2014\u5e74",
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u54c8\u5c14\u6ee8",
#                     "\u547c\u548c\u6d69\u7279",
#                     "\u94f6\u5ddd",
#                     "\u4e0a\u6d77",
#                     "\u77f3\u5bb6\u5e84",
#                     "\u5929\u6d25",
#                     "\u5357\u660c",
#                     "\u957f\u6625",
#                     "\u6210\u90fd",
#                     "\u592a\u539f",
#                     "\u897f\u5b89",
#                     "\u53a6\u95e8",
#                     "\u6c88\u9633",
#                     "\u8d35\u9633",
#                     "\u6606\u660e",
#                     "\u4e4c\u9c81\u6728\u9f50",
#                     "\u91cd\u5e86",
#                     "\u9752\u5c9b",
#                     "\u5408\u80a5",
#                     "\u5927\u8fde",
#                     "\u90d1\u5dde",
#                     "\u957f\u6c99",
#                     "\u897f\u5b81",
#                     "\u798f\u5dde",
#                     "\u5357\u5b81",
#                     "\u6df1\u5733",
#                     "\u62c9\u8428",
#                     "\u6b66\u6c49",
#                     "\u5170\u5dde",
#                     "\u6d4e\u5357",
#                     "\u5e7f\u5dde",
#                     "\u5b81\u6ce2",
#                     "\u5357\u4eac",
#                     "\u676d\u5dde",
#                     "\u5317\u4eac",
#                     "\u6d77\u53e3"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "min": 0,
#                 "max": 4.5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ],
#         "visualMap": {
#             "show": true,
#             "type": "continuous",
#             "min": 0,
#             "max": 4.5,
#             "inRange": {
#                 "color": [
#                     "#50a3ba",
#                     "#eac763",
#                     "#d94e5d"
#                 ]
#             },
#             "calculable": true,
#             "splitNumber": 5,
#             "orient": "vertical",
#             "showLabel": true,
#             "itemWidth": 20,
#             "itemHeight": 140
#         },
#         "dataZoom": {
#             "show": true,
#             "type": "inside",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5931\u4e1a\u7387"
#                     ],
#                     "selected": {
#                         "\u5931\u4e1a\u7387": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         3.72,
#                         3.5,
#                         4.09,
#                         4.2,
#                         4.1,
#                         3.5,
#                         3.27,
#                         3.75,
#                         2.87,
#                         3.4,
#                         3.4,
#                         3.03,
#                         3.03,
#                         3.14,
#                         2.34,
#                         3.56,
#                         3.5,
#                         2.97,
#                         2.96,
#                         2.65,
#                         1.37,
#                         2.85,
#                         2.98,
#                         2.42,
#                         2.95,
#                         2.26,
#                         2.0,
#                         3.15,
#                         1.77,
#                         2.24,
#                         2.26,
#                         1.95,
#                         2.68,
#                         1.84,
#                         1.31,
#                         1.37
#                     ]
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "widt

# %% [markdown]
# 失业率和就业率存在反比关系，失业低则意味着就业率高，同时也意味着就业竞争压力小。在国家积极的就业政策背景下，近5年来大多数城市的失业率稳中有降，但仍有些城市的失业率始终在上升或者失业率始终维持在较高水平。例如成都近5年的失业率一直在上升；哈尔滨的失业率始终保持一年升一年降的趋势，但变化起伏不大，近5年来失业率始终保持在36个主要城市中的前5名。并且东北以及靠近东北的北方地区的失业率大多数都非常高，近5年的失业率基本都高于36个城市的平均失业率。而近5年失业率始终保持较低水平且无明显上升趋势的城市主要有南京、杭州、宁波、海口以及除深圳外的一线城市等。

# %% [markdown]
# ## 总结（36个主要城市六个维度排名总和）

# %%
df5 = pd.read_csv("生活压力排名.csv",encoding='gbk')
df5[['地区','排名总和']].head()
# Out:
#     地区  排名总和
# 0   厦门    41
# 1   上海    47
# 2   天津    65
# 3   深圳    65
# 4  石家庄    77

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page

def funnel_label_inside() -> Funnel:
    c = (
        Funnel()
        .add(
            "排名总和",
            [list(z) for z in zip(df5['地区'], df5['排名总和'])],
            label_opts=opts.LabelOpts(position="inside"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="36个主要城市六个维度排名总和"),
                        legend_opts=opts.LegendOpts(type_='scroll',pos_top=25)
                        )
    )
    return c

# %%
funnel_label_inside().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3bb54bbcdccf40c9ae32e6f9ffeab331" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3bb54bbcdccf40c9ae32e6f9ffeab331 = echarts.init(
#                     document.getElementById('3bb54bbcdccf40c9ae32e6f9ffeab331'), 'white', {renderer: 'canvas'});
#                 var option_3bb54bbcdccf40c9ae32e6f9ffeab331 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u6392\u540d\u603b\u548c",
#             "data": [
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u798f\u5dde",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u5357\u660c",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": 88
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": 88
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u592a\u539f",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u5b81\u6ce2",
#                     "value": 94
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": 94
#                 },
#                 {
#                     "name": "\u8d35\u9633",
#                     "value": 96
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u957f\u6625",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u94f6\u5ddd",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u5927\u8fde",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u897f\u5b81",
#                     "value": 132
#                 },
#                 {
#                     "name": "\u5170\u5dde",
#                     "value": 142
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u592a\u539f",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u6d77\u53e3",
#                 "\u4e4c\u9c81\u6728\u9f50",
#                 "\u5408\u80a5",
#                 "\u9752\u5c9b",
#                 "\u5929\u6d25",
#                 "\u94f6\u5ddd",
#                 "\u5e7f\u5dde",
#                 "\u897f\u5b89",
#                 "\u5927\u8fde",
#                 "\u5357\u4eac",
#                 "\u547c\u548c\u6d69\u7279",
#                 "\u53a6\u95e8",
#                 "\u77f3\u5bb6\u5e84",
#                 "\u5170\u5dde",
#                 "\u6210\u90fd",
#                 "\u6df1\u5733",
#                 "\u897f\u5b81",
#                 "\u91cd\u5e86",
#                 "\u957f\u6625",
#                 "\u676d\u5dde",
#                 "\u6b66\u6c49",
#                 "\u5357\u660c",
#                 "\u798f\u5dde",
#                 "\u5317\u4eac",
#                 "\u5b81\u6ce2",
#                 "\u957f\u6c99",
#                 "\u4e0a\u6d77",
#                 "\u6c88\u9633",
#                 "\u6d4e\u5357",
#                 "\u90d1\u5dde",
#                 "\u8d35\u9633"
#             ],
#             "selected": {
#                 "\u53a6\u95e8": true,
#                 "\u4e0a\u6d77": true,
#                 "\u5929\u6d25": true,
#                 "\u6df1\u5733": true,
#                 "\u77f3\u5bb6\u5e84": true,
#                 "\u897f\u5b89": true,
#                 "\u547c\u548c\u6d69\u7279": true,
#                 "\u798f\u5dde": true,
#                 "\u5e7f\u5dde": true,
#                 "\u6210\u90fd": true,
#                 "\u9752\u5c9b": true,
#                 "\u6b66\u6c49": true,
#                 "\u5357\u660c": true,
#                 "\u54c8\u5c14\u6ee8": true,
#                 "\u5357\u4eac": true,
#                 "\u6c88\u9633": true,
#                 "\u90d1\u5dde": true,
#                 "\u5317\u4eac": true,
#                 "\u592a\u539f": true,
#                 "\u5408\u80a5": true,
#                 "\u5b81\u6ce2": true,
#                 "\u6d77\u53e3": true,
#                 "\u8d35\u9633": true,
#                 "\u676d\u5dde": true,
#                 "\u957f\u6625": true,
#                 "\u6d4e\u5357": true,
#                 "\u94f6\u5ddd": true,
#                 "\u91cd\u5e86": true,
#                 "\u957f\u6c99": true,
#                 "\u5927\u8fde": true,
#                 "\u4e4c\u9c81\u6728\u9f50": true,
#                 "\u897f\u5b81": true,
#                 "\u5170\u5dde": true
#             },
#             "type": "scroll",
#             "show": true,
#             "top": 25,
#             "padding": 5,

# %% [markdown]
# 本项目从人口密度、人均消费支出、平均薪资、住宅商品房房价和失业率六个维度探索了我国36个主要城市的生活压力。通过对2018年36个城市的六个维度进行了排名的总和计算，排名总和与生活压力成反比关系，即总和越高的城市，其居民的生活压力越低。在大多数人都渴望能够立足的一线城市中，除了失业率外，一线城市的每一维度基本都位于前列。那么从排名总和来看，一线城市中生活压力较低的是北京，最高的是上海。除住宅商品房房价外，北京在其余方面基本都优于其他一线城市。那么与人口流入收紧、就业竞争激烈的一线城市相比，其余的32个主要城市的排名总和又是怎样的呢？在二线城市中，兰州的生活压力是最低的，除平均薪资外，其余5个方面都位居前8名。而作为非一线城市和新一线城市的厦门的生活压力却是最高的，甚至是所有城市中最高的。虽然厦门生活压力如此大，但仍有许多人选择生活在厦门，或许厦门留有令人心动的方面？在三线城市中西宁的生活压力是最低的，海口是最高的（缺乏拉萨的完整数据）。
